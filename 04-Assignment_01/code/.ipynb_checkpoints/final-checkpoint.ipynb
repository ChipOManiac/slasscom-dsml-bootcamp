# %%
# 1. Import libraries.

import pandas as pd
import numpy as np # IDK, do I really need this?
import matplotlib

# %%
# 2. Max out display of columns at 20.

pd.set_option("display.max_columns", 20)

# %%
# 3. Setup the column headings for the data-sets.

column_headings = [
    "Age",
    "Sex",
    "ChestPainType",
    "BloodPressure",
    "SerumCholestrol",
    "FastingBloodSugarOver120",
    "ECGAtRest",
    "MaxHeartRate",
    "HasExerciseInducedAngina",
    "STDepression",
    "STSlope",
    "FlouroscopyMajorVessels",
    "Thal",
    "Diagnosis"
]

# %%
# 4. Read in the first data-set (Cleveland).

df1_raw = pd.read_csv('../data-sets/processed.cleveland.data', names=column_headings)

# %%
#    Display dimensions.

df1_raw.shape
# Out:
# (303, 14)

# %%
#    Head the data.

df1_raw.head(10)
# Out:
#     Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0  63.0  1.0            1.0          145.0            233.0
# 1  67.0  1.0            4.0          160.0            286.0
# 2  67.0  1.0            4.0          120.0            229.0
# 3  37.0  1.0            3.0          130.0            250.0
# 4  41.0  0.0            2.0          130.0            204.0
# 5  56.0  1.0            2.0          120.0            236.0
# 6  62.0  0.0            4.0          140.0            268.0
# 7  57.0  0.0            4.0          120.0            354.0
# 8  63.0  1.0            4.0          130.0            254.0
# 9  53.0  1.0            4.0          140.0            203.0
#
#    FastingBloodSugarOver120  ECGAtRest  MaxHeartRate  \
# 0                       1.0        2.0         150.0
# 1                       0.0        2.0         108.0
# 2                       0.0        2.0         129.0
# 3                       0.0        0.0         187.0
# ...

# %%
# 5. Do some preliminary cleanup of dtypes.

df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int",
    "Thal":"int",
    "Diagnosis":"int"
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 5. Do some preliminary cleanup of dtypes.
# ----> 3 df1_raw.astype({
#       4     "Age":"int",
#       5     "Sex":"int",
#       6     "ChestPainType":"int",
#       7     "BloodPressure":"float",
#       8     "SerumCholestrol":"float",
#       9     "FastingBloodSugarOver120":"int",
#      10     "ECGAtRest":"int",
#      11     "MaxHeartRate":"float",
#      12     "HasExerciseInducedAngina":"int",
#      13     "STDepression":"float",
#      14     "STSlope":"int",
#      15     "FlouroscopyMajorVessels":"int",
#      16     "Thal":"int",
#      17     "Diagnosis":"int"
#      18 })
#
# File ~/Code/Non-Packaged/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
# ...

# %%
# 6. Whoops, looks like we have some errors. Let's go one by one and see which.

df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
})

# %%
# 7. Error clears at 'FlouroscopyMajorVessels', let's take a look at that.

df1_raw['FlouroscopyMajorVessels']
# Out:
# 0      0.0
# 1      3.0
# 2      2.0
# 3      0.0
# 4      0.0
#       ...
# 298    0.0
# 299    2.0
# 300    1.0
# 301    1.0
# 302      ?
# Name: FlouroscopyMajorVessels, Length: 303, dtype: object

# %%
# 8. Lookie here, there's a '?', possibly for a missing piece of data. Let's look for others.

df1_raw.loc[df1_raw['FlouroscopyMajorVessels'] == '?']
# Out:
#       Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 166  52.0  1.0            3.0          138.0            223.0
# 192  43.0  1.0            4.0          132.0            247.0
# 287  58.0  1.0            2.0          125.0            220.0
# 302  38.0  1.0            3.0          138.0            175.0
#
#      FastingBloodSugarOver120  ECGAtRest  MaxHeartRate  \
# 166                       0.0        0.0         169.0
# 192                       1.0        2.0         143.0
# 287                       0.0        0.0         144.0
# 302                       0.0        0.0         173.0
#
#      HasExerciseInducedAngina  STDepression  STSlope FlouroscopyMajorVessels  \
# 166                       0.0           0.0      1.0                       ?
# 192                       1.0           0.1      2.0                       ?
# 287                       0.0           0.4      2.0                       ?
# ...

# %%
# 9. Three values. Let's get rid of them.

df1_raw = df1_raw.drop(axis=1, index=[166,192,287,302])

# %%
# 10. Let's try the dtype again.

df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int"
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 # 10. Let's try the dtype again.
# ----> 3 df1_raw.astype({
#       4     "Age":"int",
#       5     "Sex":"int",
#       6     "ChestPainType":"int",
#       7     "BloodPressure":"float",
#       8     "SerumCholestrol":"float",
#       9     "FastingBloodSugarOver120":"int",
#      10     "ECGAtRest":"int",
#      11     "MaxHeartRate":"float",
#      12     "HasExerciseInducedAngina":"int",
#      13     "STDepression":"float",
#      14     "STSlope":"int",
#      15     "FlouroscopyMajorVessels":"int"
#      16 })
#
# File ~/Code/Non-Packaged/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
#    6225         else:
# ...

# %%
# 11. Looks like converting to int directly doesn't happen, let's convert to float first and then to int.

df1_raw = df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"float"
})

df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int"
})
# Out:
#      Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0     63    1              1          145.0            233.0
# 1     67    1              4          160.0            286.0
# 2     67    1              4          120.0            229.0
# 3     37    1              3          130.0            250.0
# 4     41    0              2          130.0            204.0
# ..   ...  ...            ...            ...              ...
# 297   57    0              4          140.0            241.0
# 298   45    1              1          110.0            264.0
# 299   68    1              4          144.0            193.0
# 300   57    1              4          130.0            131.0
# 301   57    0              2          130.0            236.0
#
#      FastingBloodSugarOver120  ECGAtRest  MaxHeartRate  \
# 0                           1          2         150.0
# 1                           0          2         108.0
# 2                           0          2         129.0
# ...

# %%
# 12. That worked. Move on to the next one.

df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int",
    "Thal":"int"
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # 12. That worked. Move on to the next one.
# ----> 3 df1_raw.astype({
#       4     "Age":"int",
#       5     "Sex":"int",
#       6     "ChestPainType":"int",
#       7     "BloodPressure":"float",
#       8     "SerumCholestrol":"float",
#       9     "FastingBloodSugarOver120":"int",
#      10     "ECGAtRest":"int",
#      11     "MaxHeartRate":"float",
#      12     "HasExerciseInducedAngina":"int",
#      13     "STDepression":"float",
#      14     "STSlope":"int",
#      15     "FlouroscopyMajorVessels":"int",
#      16     "Thal":"int"
#      17 })
#
# File ~/Code/Non-Packaged/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
#    6225         else:
# ...

# %%
# 13. Looks like 'Thal' has the same issue. Let's see.

df1_raw['Thal']
# Out:
# 0      6.0
# 1      3.0
# 2      7.0
# 3      3.0
# 4      3.0
#       ...
# 297    7.0
# 298    7.0
# 299    7.0
# 300    7.0
# 301    3.0
# Name: Thal, Length: 299, dtype: object

# %%
# 14. Probably using '?' for missing.

df1_raw.loc[df1_raw['Thal'] == '?']
# Out:
#      Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 87    53    0              3          128.0            216.0
# 266   52    1              4          128.0            204.0
#
#      FastingBloodSugarOver120  ECGAtRest  MaxHeartRate  \
# 87                          0          2         115.0
# 266                         1          0         156.0
#
#      HasExerciseInducedAngina  STDepression  STSlope  FlouroscopyMajorVessels  \
# 87                          0           0.0        1                      0.0
# 266                         1           1.0        2                      0.0
#
#     Thal  Diagnosis
# 87     ?          0
# 266    ?          2

# %%
# 15. Two records, getting rid of them.

df1_raw = df1_raw.drop(axis=1, index=[87,266])

# %%
# 16. Retry the astype, float first.

df1_raw = df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int",
    "Thal":"float"
})

df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int",
    "Thal":"int"
})
# Out:
#      Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0     63    1              1          145.0            233.0
# 1     67    1              4          160.0            286.0
# 2     67    1              4          120.0            229.0
# 3     37    1              3          130.0            250.0
# 4     41    0              2          130.0            204.0
# ..   ...  ...            ...            ...              ...
# 297   57    0              4          140.0            241.0
# 298   45    1              1          110.0            264.0
# 299   68    1              4          144.0            193.0
# 300   57    1              4          130.0            131.0
# 301   57    0              2          130.0            236.0
#
#      FastingBloodSugarOver120  ECGAtRest  MaxHeartRate  \
# 0                           1          2         150.0
# 1                           0          2         108.0
# 2                           0          2         129.0
# ...

# %%
# 17. Looks clean. Finish it off.

df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int",
    "Thal":"int",
    "Diagnosis":"int"
})
# Out:
#      Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0     63    1              1          145.0            233.0
# 1     67    1              4          160.0            286.0
# 2     67    1              4          120.0            229.0
# 3     37    1              3          130.0            250.0
# 4     41    0              2          130.0            204.0
# ..   ...  ...            ...            ...              ...
# 297   57    0              4          140.0            241.0
# 298   45    1              1          110.0            264.0
# 299   68    1              4          144.0            193.0
# 300   57    1              4          130.0            131.0
# 301   57    0              2          130.0            236.0
#
#      FastingBloodSugarOver120  ECGAtRest  MaxHeartRate  \
# 0                           1          2         150.0
# 1                           0          2         108.0
# 2                           0          2         129.0
# ...

# %%
# 18. Assign to the final data-frame.

df1 = df1_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int",
    "Thal":"int",
    "Diagnosis":"int"
})

# %%
# 19. Do the same thing for the other data-sets.

df2_raw = pd.read_csv('../data-sets/processed.hungarian.data', names=column_headings)

df2_raw.shape
# Out:
# (294, 14)

# %%
# 20. Try the dtype setting again.

df2_raw.astype({
    "Age":"int",
    "Sex":"int",
    "ChestPainType":"int",
    "BloodPressure":"float",
    "SerumCholestrol":"float",
    "FastingBloodSugarOver120":"int",
    "ECGAtRest":"int",
    "MaxHeartRate":"float",
    "HasExerciseInducedAngina":"int",
    "STDepression":"float",
    "STSlope":"int",
    "FlouroscopyMajorVessels":"int",
    "Thal":"int",
    "Diagnosis":"int"
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 3
#       1 # 20. Try the dtype setting again.
# ----> 3 df2_raw.astype({
#       4     "Age":"int",
#       5     "Sex":"int",
#       6     "ChestPainType":"int",
#       7     "BloodPressure":"float",
#       8     "SerumCholestrol":"float",
#       9     "FastingBloodSugarOver120":"int",
#      10     "ECGAtRest":"int",
#      11     "MaxHeartRate":"float",
#      12     "HasExerciseInducedAngina":"int",
#      13     "STDepression":"float",
#      14     "STSlope":"int",
#      15     "FlouroscopyMajorVessels":"int",
#      16     "Thal":"int",
#      17     "Diagnosis":"int"
#      18 })
#
# File ~/Code/Non-Packaged/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
# ...

# %%
# 21. Great -_- more missings.

df2_raw.isin(['?']).any(axis=1).count
# Out:
# <bound method Series.count of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 289    True
# 290    True
# 291    True
# 292    True
# 293    True
# Length: 294, dtype: bool>

# %%
# 22. Whole set is usless. Onto the next data-set.

df3_raw = pd.read_csv('../data-sets/processed.switzerland.data', names=column_headings)

df3_raw.shape
# Out:
# (123, 14)

# %%
# 23. Searching for missings beforehand.

df3_raw.isin(['?']).any(axis=1).count
# Out:
# <bound method Series.count of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 118    True
# 119    True
# 120    True
# 121    True
# 122    True
# Length: 123, dtype: bool>

# %%
# 24. Whole set is useless. Moving to next set.

df4_raw = pd.read_csv('../data-sets/processed.va.data', names=column_headings)

df4_raw.shape
# Out:
# (200, 14)

# %%
# 25. Searching for missings beforehand.

df4_raw.isin(['?']).any(axis=1).count
# Out:
# <bound method Series.count of 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 195    True
# 196    True
# 197    True
# 198    True
# 199    True
# Length: 200, dtype: bool>

# %%
# 26. Cleaning up some values in 'Diagnosis'.

df1_1 = df1.astype({"Diagnosis":"bool"})
df1_chart = df1_1.astype({"Diagnosis":"int"})
df1_chart
# Out:
#      Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0     63    1              1          145.0            233.0
# 1     67    1              4          160.0            286.0
# 2     67    1              4          120.0            229.0
# 3     37    1              3          130.0            250.0
# 4     41    0              2          130.0            204.0
# ..   ...  ...            ...            ...              ...
# 297   57    0              4          140.0            241.0
# 298   45    1              1          110.0            264.0
# 299   68    1              4          144.0            193.0
# 300   57    1              4          130.0            131.0
# 301   57    0              2          130.0            236.0
#
#      FastingBloodSugarOver120  ECGAtRest  MaxHeartRate  \
# 0                           1          2         150.0
# 1                           0          2         108.0
# 2                           0          2         129.0
# ...

# %%
# 27. Create graphs.

#     Histograms
df1_chart.groupby('Diagnosis')['Sex'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Sex')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Sex, dtype: object

# %%
df1_chart.groupby('Diagnosis')['Age'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Age')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %%
df1_chart.groupby('Diagnosis')['ChestPainType'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Chest Pain Area')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: ChestPainType, dtype: object

# %%
df1_chart.groupby('Diagnosis')['BloodPressure'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by BloodPressure')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: BloodPressure, dtype: object

# %%
df1_chart.groupby('Diagnosis')['SerumCholestrol'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Serum Cholestrol')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: SerumCholestrol, dtype: object

# %%
df1_chart.groupby('Diagnosis')['FastingBloodSugarOver120'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Fasting Blood Sugar Over 120')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: FastingBloodSugarOver120, dtype: object

# %%
df1_chart.groupby('Diagnosis')['ECGAtRest'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by ECG at Rest')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: ECGAtRest, dtype: object

# %%
df1_chart.groupby('Diagnosis')['MaxHeartRate'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Max. Heart Rate')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: MaxHeartRate, dtype: object

# %%
df1_chart.groupby('Diagnosis')['HasExerciseInducedAngina'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Prescense of Exercise Induced Angina')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: HasExerciseInducedAngina, dtype: object

# %%
df1_chart.groupby('Diagnosis')['STDepression'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Prescense of ST Depression')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: STDepression, dtype: object

# %%
df1_chart.groupby('Diagnosis')['STSlope'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by ST Depression Slope')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: STSlope, dtype: object

# %%
df1_chart.groupby('Diagnosis')['FlouroscopyMajorVessels'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Major Vessel Count in Fluroscopy')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: FlouroscopyMajorVessels, dtype: object

# %%
df1_chart.groupby('Diagnosis')['Thal'].plot(kind='hist', legend=True, alpha=0.5, title='Diagnosis by Thal')
# Out:
# Diagnosis
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Thal, dtype: object

# %%
#     Scatter-plots
df1_chart[['Diagnosis','Age']].plot(
    kind='scatter', 
    title='Diagnosis by Age', 
    x='Age', 
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Age'}, xlabel='Age', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','Sex']].plot(
    kind='scatter', 
    title='Diagnosis by Sex', 
    x='Sex', 
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Sex'}, xlabel='Sex', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','ChestPainType']].plot(
    kind='scatter', 
    title='Diagnosis by Chest Pain Type', 
    x='ChestPainType', 
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Chest Pain Type'}, xlabel='ChestPainType', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','BloodPressure']].plot(
    kind='scatter', 
    title='Diagnosis by Blood Pressure', 
    x='BloodPressure', 
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Blood Pressure'}, xlabel='BloodPressure', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','SerumCholestrol']].plot(
    kind='scatter', 
    title='Diagnosis by Serum Cholesterol',
    x='SerumCholestrol',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Serum Cholesterol'}, xlabel='SerumCholestrol', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','FastingBloodSugarOver120']].plot(
    kind='scatter', 
    title='Diagnosis by Fasting Blood Sugar Over 120',
    x='FastingBloodSugarOver120',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Fasting Blood Sugar Over 120'}, xlabel='FastingBloodSugarOver120', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','ECGAtRest']].plot(
    kind='scatter', 
    title='Diagnosis by ECG At Rest',
    x='ECGAtRest',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by ECG At Rest'}, xlabel='ECGAtRest', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','MaxHeartRate']].plot(
    kind='scatter', 
    title='Diagnosis by Max. Heart Rate',
    x='MaxHeartRate',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Max. Heart Rate'}, xlabel='MaxHeartRate', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','HasExerciseInducedAngina']].plot(
    kind='scatter', 
    title='Diagnosis by Presence of Exercise Induced Angina',
    x='HasExerciseInducedAngina',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Presence of Exercise Induced Angins'}, xlabel='HasExerciseInducedAngina', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','STDepression']].plot(
    kind='scatter', 
    title='Diagnosis by Presence of ST Depression',
    x='STDepression',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Presence of ST Depression'}, xlabel='STDepression', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','STSlope']].plot(
    kind='scatter', 
    title='Diagnosis by Presence of ST Depression Slope',
    x='STSlope',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Presence of ST Depression Slope'}, xlabel='STSlope', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','FlouroscopyMajorVessels']].plot(
    kind='scatter', 
    title='Diagnosis by Major Vessel Count in Fluroscopy',
    x='FlouroscopyMajorVessels',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Major Vessel Count in Fluroscopy'}, xlabel='FlouroscopyMajorVessels', ylabel='Diagnosis'>

# %%
df1_chart[['Diagnosis','Thal']].plot(
    kind='scatter', 
    title='Diagnosis by Thal',
    x='Thal',
    y='Diagnosis'
)
# Out:
# <Axes: title={'center': 'Diagnosis by Thal'}, xlabel='Thal', ylabel='Diagnosis'>
