# %%
# 1. Import the required libraries

import pandas as pd
import numpy as np
import matplotlib

# %%
# 2. Set the columns

column_headers = [
    "Age",
    "Sex",
    "ChestPainType",
    "BloodPressure",
    "SerumCholestrol",
    "FastingBloodSugarOver120",
    "ECGAtRest",
    "HasExerciseInducedAngina",
    "MaxHeartRate",
    "STDepression",
    "STSlope",
    "FlouroscopyMajorVessels",
    "Thal",
    "Diagnosis"
]

# %%
# 3. Load in the first data-set (Cleveland)

df1 = pd.read_csv(
    "../data-sets/processed.cleveland.data",
    names=column_headers
)

df1.head(5)
# Out:
#     Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0  63.0  1.0            1.0          145.0            233.0
# 1  67.0  1.0            4.0          160.0            286.0
# 2  67.0  1.0            4.0          120.0            229.0
# 3  37.0  1.0            3.0          130.0            250.0
# 4  41.0  0.0            2.0          130.0            204.0
#
#    FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 0                       1.0        2.0                     150.0
# 1                       0.0        2.0                     108.0
# 2                       0.0        2.0                     129.0
# 3                       0.0        0.0                     187.0
# 4                       0.0        2.0                     172.0
#
#    MaxHeartRate  STDepression  STSlope FlouroscopyMajorVessels Thal  Diagnosis
# 0           0.0           2.3      3.0                     0.0  6.0          0
# 1           1.0           1.5      2.0                     3.0  3.0          2
# 2           1.0           2.6      2.0                     2.0  7.0          1
# 3           0.0           3.5      3.0                     0.0  3.0          0
# 4           0.0           1.4      1.0                     0.0  3.0          0

# %%
# 4. Let's set the dtypes

df1.astype({
    'Age':'int',
    'Sex':'int',
    'ChestPainType':'int',
    'FastingBloodSugarOver120':'bool',
    'ECGAtRest':'int',
    'HasExerciseInducedAngina':'bool',
    'MaxHeartRate':'int',
    'STSlope':'int',
    'Diagnosis':'bool'
})
# Out:
#      Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0     63    1              1          145.0            233.0
# 1     67    1              4          160.0            286.0
# 2     67    1              4          120.0            229.0
# 3     37    1              3          130.0            250.0
# 4     41    0              2          130.0            204.0
# ..   ...  ...            ...            ...              ...
# 298   45    1              1          110.0            264.0
# 299   68    1              4          144.0            193.0
# 300   57    1              4          130.0            131.0
# 301   57    0              2          130.0            236.0
# 302   38    1              3          138.0            175.0
#
#      FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 0                        True          2                      True
# 1                       False          2                      True
# 2                       False          2                      True
# 3                       False          0                      True
# 4                       False          2                      True
# ..                        ...        ...                       ...
# 298                     False          0                      True
# 299                      True          0                      True
# 300                     False          0                      True
# 301                     False          2                      True
# 302                     False          0                      True
#
#      MaxHeartRate  STDepression  STSlope FlouroscopyMajorVessels Thal  \
# 0               0           2.3        3                     0.0  6.0
# 1               1           1.5        2                     3.0  3.0
# 2               1           2.6        2                     2.0  7.0
# 3               0           3.5        3                     0.0  3.0
# 4               0           1.4        1                     0.0  3.0
# ..            ...           ...      ...                     ...  ...
# 298             0           1.2        2                     0.0  7.0
# 299             0           3.4        2                     2.0  7.0
# 300             1           1.2        2                     1.0  7.0
# 301             0           0.0        2                     1.0  3.0
# 302             0           0.0        1                       ?  3.0
#
#      Diagnosis
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
# ..         ...
# 298       True
# 299       True
# 300       True
# 301       True
# 302      False
#
# [303 rows x 14 columns]

# %%
# 5. Looks like "Thal" doesn't like being assigned as an integer.
#    In other data-sets, several columns had '?' as a value, lets
#    see if it's so here.

df1.loc[df1['Thal'] == '?']
# Out:
#       Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 87   53.0  0.0            3.0          128.0            216.0
# 266  52.0  1.0            4.0          128.0            204.0
#
#      FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 87                        0.0        2.0                     115.0
# 266                       1.0        0.0                     156.0
#
#      MaxHeartRate  STDepression  STSlope FlouroscopyMajorVessels Thal  \
# 87            0.0           0.0      1.0                     0.0    ?
# 266           1.0           1.0      2.0                     0.0    ?
#
#      Diagnosis
# 87           0
# 266          2

# %%
# 6. Yes there is. Get rid of both of them.

df1_1 = df1.drop(axis=1, index=[87,266])

# %%
df1_1 = df1_1.astype({
    'Age':'int',
    'Sex':'int',
    'ChestPainType':'int',
    'FastingBloodSugarOver120':'bool',
    'ECGAtRest':'int',
    'HasExerciseInducedAngina':'bool',
    'MaxHeartRate':'int',
    'STSlope':'int',
    'Thal':'float',
    'Diagnosis':'bool'
})

# %%
df1_1 = df1_1.astype({
    'Age':'int',
    'Sex':'int',
    'ChestPainType':'int',
    'FastingBloodSugarOver120':'bool',
    'ECGAtRest':'int',
    'HasExerciseInducedAngina':'bool',
    'MaxHeartRate':'int',
    'STSlope':'int',
    'Thal':'int',
    'Diagnosis':'bool'
})

# %%
df1_1.head(5)
# Out:
#    Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0   63    1              1          145.0            233.0
# 1   67    1              4          160.0            286.0
# 2   67    1              4          120.0            229.0
# 3   37    1              3          130.0            250.0
# 4   41    0              2          130.0            204.0
#
#    FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 0                      True          2                      True
# 1                     False          2                      True
# 2                     False          2                      True
# 3                     False          0                      True
# 4                     False          2                      True
#
#    MaxHeartRate  STDepression  STSlope FlouroscopyMajorVessels  Thal  \
# 0             0           2.3        3                     0.0     6
# 1             1           1.5        2                     3.0     3
# 2             1           2.6        2                     2.0     7
# 3             0           3.5        3                     0.0     3
# 4             0           1.4        1                     0.0     3
#
#    Diagnosis
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False

# %%
df1.loc[df1['FlouroscopyMajorVessels'] == '?']
# Out:
#       Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 166  52.0  1.0            3.0          138.0            223.0
# 192  43.0  1.0            4.0          132.0            247.0
# 287  58.0  1.0            2.0          125.0            220.0
# 302  38.0  1.0            3.0          138.0            175.0
#
#      FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 166                       0.0        0.0                     169.0
# 192                       1.0        2.0                     143.0
# 287                       0.0        0.0                     144.0
# 302                       0.0        0.0                     173.0
#
#      MaxHeartRate  STDepression  STSlope FlouroscopyMajorVessels Thal  \
# 166           0.0           0.0      1.0                       ?  3.0
# 192           1.0           0.1      2.0                       ?  7.0
# 287           0.0           0.4      2.0                       ?  7.0
# 302           0.0           0.0      1.0                       ?  3.0
#
#      Diagnosis
# 166          0
# 192          1
# 287          0
# 302          0

# %%
df1_2 = df1_1.drop(axis=1, index=[166,192,287,302])

# %%
df1_2.head()
# Out:
#    Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0   63    1              1          145.0            233.0
# 1   67    1              4          160.0            286.0
# 2   67    1              4          120.0            229.0
# 3   37    1              3          130.0            250.0
# 4   41    0              2          130.0            204.0
#
#    FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 0                      True          2                      True
# 1                     False          2                      True
# 2                     False          2                      True
# 3                     False          0                      True
# 4                     False          2                      True
#
#    MaxHeartRate  STDepression  STSlope FlouroscopyMajorVessels  Thal  \
# 0             0           2.3        3                     0.0     6
# 1             1           1.5        2                     3.0     3
# 2             1           2.6        2                     2.0     7
# 3             0           3.5        3                     0.0     3
# 4             0           1.4        1                     0.0     3
#
#    Diagnosis
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False

# %%
df1_2 = df1_2.astype({'FlouroscopyMajorVessels':'float'})
df1_2 = df1_2.astype({'FlouroscopyMajorVessels':'int'})

# %%
df1_2.head()
# Out:
#    Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0   63    1              1          145.0            233.0
# 1   67    1              4          160.0            286.0
# 2   67    1              4          120.0            229.0
# 3   37    1              3          130.0            250.0
# 4   41    0              2          130.0            204.0
#
#    FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 0                      True          2                      True
# 1                     False          2                      True
# 2                     False          2                      True
# 3                     False          0                      True
# 4                     False          2                      True
#
#    MaxHeartRate  STDepression  STSlope  FlouroscopyMajorVessels  Thal  \
# 0             0           2.3        3                        0     6
# 1             1           1.5        2                        3     3
# 2             1           2.6        2                        2     7
# 3             0           3.5        3                        0     3
# 4             0           1.4        1                        0     3
#
#    Diagnosis
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False

# %%
df1_2 = df1_2.astype({'BloodPressure':'float', 'SerumCholestrol':'float', 'STDepression':'float'})

# %%
df1_2.head()
# Out:
#    Age  Sex  ChestPainType  BloodPressure  SerumCholestrol  \
# 0   63    1              1          145.0            233.0
# 1   67    1              4          160.0            286.0
# 2   67    1              4          120.0            229.0
# 3   37    1              3          130.0            250.0
# 4   41    0              2          130.0            204.0
#
#    FastingBloodSugarOver120  ECGAtRest  HasExerciseInducedAngina  \
# 0                      True          2                      True
# 1                     False          2                      True
# 2                     False          2                      True
# 3                     False          0                      True
# 4                     False          2                      True
#
#    MaxHeartRate  STDepression  STSlope  FlouroscopyMajorVessels  Thal  \
# 0             0           2.3        3                        0     6
# 1             1           1.5        2                        3     3
# 2             1           2.6        2                        2     7
# 3             0           3.5        3                        0     3
# 4             0           1.4        1                        0     3
#
#    Diagnosis
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False

# %%
df_cleveland_clean
